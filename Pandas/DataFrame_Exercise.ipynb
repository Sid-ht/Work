# %%
import pandas as pd

# %%
file1=pd.read_csv('/Users/siddharth.sinha/Documents/Spark/2015-summary.csv')

# %%
file1.head()
# Out:
#   DEST_COUNTRY_NAME ORIGIN_COUNTRY_NAME  count
# 0     United States             Romania     15
# 1     United States             Croatia      1
# 2     United States             Ireland    344
# 3             Egypt       United States     15
# 4     United States               India     62

# %%
file1.shape
# Out:
# (256, 2)

# %%
file1.shape[1]
# Out:
# 3

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 256 entries, Romania to United States
# Data columns (total 2 columns):
# DEST_COUNTRY_NAME    256 non-null object
# count                256 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 6.0+ KB

# %%
file1.iloc[[90,43,23]]
# Out:
#    DEST_COUNTRY_NAME ORIGIN_COUNTRY_NAME  count
# 90          Djibouti       United States      1
# 43            Mexico       United States   7140
# 23     United States              Russia    161

# %%
file1.index[10]
# Out:
# 10

# %%
file1.index
# Out:
# RangeIndex(start=0, stop=256, step=1)

# %%
file1.columns
# Out:
# Index(['DEST_COUNTRY_NAME', 'ORIGIN_COUNTRY_NAME', 'count'], dtype='object')

# %%
file1.describe
# Out:
# <bound method NDFrame.describe of                      DEST_COUNTRY_NAME             ORIGIN_COUNTRY_NAME  count
# 0                        United States                         Romania     15
# 1                        United States                         Croatia      1
# 2                        United States                         Ireland    344
# 3                                Egypt                   United States     15
# 4                        United States                           India     62
# 5                        United States                       Singapore      1
# 6                        United States                         Grenada     62
# 7                           Costa Rica                   United States    588
# 8                              Senegal                   United States     40
# 9                              Moldova                   United States      1
# 10                       United States                    Sint Maarten    325
# ...

# %%
file1.T
# Out:
#                                0              1              2    \
# DEST_COUNTRY_NAME    United States  United States  United States
# ORIGIN_COUNTRY_NAME        Romania        Croatia        Ireland
# count                           15              1            344
#
#                                3              4              5    \
# DEST_COUNTRY_NAME            Egypt  United States  United States
# ORIGIN_COUNTRY_NAME  United States          India      Singapore
# count                           15             62              1
#
#                                6              7              8    \
# DEST_COUNTRY_NAME    United States     Costa Rica        Senegal
# ORIGIN_COUNTRY_NAME        Grenada  United States  United States
# count                           62            588             40
#
#                                9    ...            246                  247  \
# DEST_COUNTRY_NAME          Moldova  ...  United States        United States
# ...

# %%
file1.sort_index(axis=1,ascending=False)
# Out:
#      count             ORIGIN_COUNTRY_NAME                  DEST_COUNTRY_NAME
# 0       15                         Romania                      United States
# 1        1                         Croatia                      United States
# 2      344                         Ireland                      United States
# 3       15                   United States                              Egypt
# 4       62                           India                      United States
# 5        1                       Singapore                      United States
# 6       62                         Grenada                      United States
# 7      588                   United States                         Costa Rica
# 8       40                   United States                            Senegal
# 9        1                   United States                            Moldova
# 10     325                    Sint Maarten                      United States
# ...

# %%
file1.sort_values(by='ORIGIN_COUNTRY_NAME')
# Out:
#        DEST_COUNTRY_NAME                ORIGIN_COUNTRY_NAME  count
# 34         United States                             Angola     13
# 36         United States                           Anguilla     38
# 215        United States                Antigua and Barbuda    117
# 156        United States                          Argentina    141
# 102        United States                              Aruba    342
# 221        United States                          Australia    258
# 160        United States                            Austria     63
# 91         United States                         Azerbaijan     21
# 168        United States                            Bahrain      1
# 241        United States                           Barbados    130
# 150        United States                            Belgium    228
# 208        United States                             Belize    193
# 236        United States                            Bermuda    193
# ...
